# %% [markdown]
# ### 필요한 라이브러리 모아두기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 원본 데이터 확인

# %%
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### train 데이터에서 Survived 열이 없는 것 확인

# %% [markdown]
# # 각 요소별 시각화

# %%
def bar(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived, dead])
    df.index = ['Survived','Dead']
    df.plot(kind='bar', stacked=True, figsize=(10,5))

# %% [markdown]
# ### 성별에 따라

# %%
bar('Sex')

# %% [markdown]
# ### 탑승 등급에 따라

# %%
bar('Pclass')

# %% [markdown]
# ### 가족관계에 따라

# %%
bar('SibSp')

# %%
bar('Parch')

# %% [markdown]
# ### 탑승 선착장에 따라

# %%
bar('Embarked')

# %% [markdown]
# # 데이터 형식 확인하기

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %% [markdown]
# ### 데이터의 수가 부족한 열이 있음

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ### Age와 Cabin 열에서 결측치가 있는 것을 알 수 있음.

# %%
train = train[train["Age"].notnull()]
train = train[train["Cabin"].notnull()]
train = train[train["Embarked"].notnull()]
test = test[test["Age"].notnull()]
test = test[test["Cabin"].notnull()]

# %% [markdown]
# # 신분 매핑

# %%
train_test_data = [train, test]

for dataset in train_test_data :
    dataset['Title'] = dataset['Name'].str.extract('([A-Za-z]+)\.', expand=False)

# %%
train['Title'].value_counts()
# Out:
# Title
# Mr          81
# Miss        44
# Mrs         38
# Master       7
# Dr           3
# Major        2
# Mlle         2
# Mme          1
# Lady         1
# Sir          1
# Col          1
# Capt         1
# Countess     1
# Name: count, dtype: int64

# %%
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, "Master": 3, "Dr": 3, 
                 "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, 
                 "Mme": 3,"Capt": 3,"Sir": 3 }
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
train['Title'].value_counts()
# Out:
# Title
# 0    81
# 1    44
# 2    38
# 3    20
# Name: count, dtype: int64

# %%
bar('Title')

# %% [markdown]
# ### 0으로 분류된 'Mrs'가 가장 많이 죽은 것을 볼 수 있음.

# %% [markdown]
# ## Name에서 필요없는 부분 제거

# %%
train.drop('Name', axis=1, inplace=True)
test.drop('Name', axis=1, inplace=True)

# %% [markdown]
# # 성별에 따른 매핑

# %%
sex_mapping = {"male":0, "female":1}

for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %%
bar('Sex')

# %% [markdown]
# ### 생존자는 여성이, 사망자는 남성이 더 많은 것을 볼 수 있음.

# %% [markdown]
# # 나이에 따른 매핑

# %%
import numpy as np
for dataset in train_test_data:
    dataset['Age'] = np.digitize(dataset['Age'], bins=[19,39,89])  # 청소년, 청년, 노인으로 분류

# %%
bar("Age")

# %% [markdown]
# ### 0에 해당하는 청소년 탑승객이 가장 적은 사망 비율을 보이고 있음을 알 수 있다.

# %% [markdown]
# # 선착장 매핑

# %%
embarked_mapping = {"S":0, "C":1, "Q":2}
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)

# %%
bar("Embarked")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch    Ticket     Fare  \
# 1              2         1       1    1    1      1      0  PC 17599  71.2833
# 3              4         1       1    1    1      1      0    113803  53.1000
# 6              7         0       1    0    2      0      0     17463  51.8625
# 10            11         1       3    1    0      1      1   PP 9549  16.7000
# 11            12         1       1    1    2      0      0    113783  26.5500
# ..           ...       ...     ...  ...  ...    ...    ...       ...      ...
# 871          872         1       1    1    2      1      1     11751  52.5542
# 872          873         0       1    0    1      0      0       695   5.0000
# 879          880         1       1    1    2      0      1     11767  83.1583
# 887          888         1       1    1    1      0      0    112053  30.0000
# 889          890         1       1    0    1      0      0    111369  30.0000
#
# ...

# %% [markdown]
# # 요금 매핑

# %%
for dataset in train_test_data :
    dataset['Fare'] = np.digitize(dataset['Fare'], bins=[20,35,150])

# %%
train
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch    Ticket  Fare  \
# 1              2         1       1    1    1      1      0  PC 17599     2
# 3              4         1       1    1    1      1      0    113803     2
# 6              7         0       1    0    2      0      0     17463     2
# 10            11         1       3    1    0      1      1   PP 9549     0
# 11            12         1       1    1    2      0      0    113783     1
# ..           ...       ...     ...  ...  ...    ...    ...       ...   ...
# 871          872         1       1    1    2      1      1     11751     2
# 872          873         0       1    0    1      0      0       695     0
# 879          880         1       1    1    2      0      1     11767     2
# 887          888         1       1    1    1      0      0    112053     1
# 889          890         1       1    0    1      0      0    111369     1
#
#            Cabin  Embarked  Title
# ...

# %% [markdown]
# # 객실 번호 매핑

# %%
for dataset in train_test_data:
    dataset['Cabin']=dataset['Cabin'].str[:1]

# %%
cabin_mapping = {"A": 1, "B": 2, "C": 3, "D": 4, "E": 5, "F": 6, "G": 7, "T": 8}
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].map(cabin_mapping)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch    Ticket  Fare  \
# 1              2         1       1    1    1      1      0  PC 17599     2
# 3              4         1       1    1    1      1      0    113803     2
# 6              7         0       1    0    2      0      0     17463     2
# 10            11         1       3    1    0      1      1   PP 9549     0
# 11            12         1       1    1    2      0      0    113783     1
# ..           ...       ...     ...  ...  ...    ...    ...       ...   ...
# 871          872         1       1    1    2      1      1     11751     2
# 872          873         0       1    0    1      0      0       695     0
# 879          880         1       1    1    2      0      1     11767     2
# 887          888         1       1    1    1      0      0    112053     1
# 889          890         1       1    0    1      0      0    111369     1
#
#      Cabin  Embarked  Title
# 1        3         1      2
# ...

# %% [markdown]
# # 가족 관계 매핑

# %%
train["FamilySize"] = train["SibSp"]+train["Parch"]
test["FamilySize"] = test["SibSp"]+test["Parch"]

# %%
train
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch    Ticket  Fare  \
# 1              2         1       1    1    1      1      0  PC 17599     2
# 3              4         1       1    1    1      1      0    113803     2
# 6              7         0       1    0    2      0      0     17463     2
# 10            11         1       3    1    0      1      1   PP 9549     0
# 11            12         1       1    1    2      0      0    113783     1
# ..           ...       ...     ...  ...  ...    ...    ...       ...   ...
# 871          872         1       1    1    2      1      1     11751     2
# 872          873         0       1    0    1      0      0       695     0
# 879          880         1       1    1    2      0      1     11767     2
# 887          888         1       1    1    1      0      0    112053     1
# 889          890         1       1    0    1      0      0    111369     1
#
#      Cabin  Embarked  Title  FamilySize
# ...

# %% [markdown]
# # 불필요한 열 제거

# %%
features_drop = ['Ticket','SibSp','Parch']
train = train.drop(features_drop,axis=1)
test = test.drop(features_drop, axis=1)

train=train.drop(['PassengerId'],axis=1)

train_data = train.drop('Survived',axis=1)
target = train['Survived']

# %%
train
# Out:
#      Survived  Pclass  Sex  Age  Fare  Cabin  Embarked  Title  FamilySize
# 1           1       1    1    1     2      3         1      2           1
# 3           1       1    1    1     2      3         0      2           1
# 6           0       1    0    2     2      5         0      0           0
# 10          1       3    1    0     0      7         0      1           2
# 11          1       1    1    2     1      3         0      1           0
# ..        ...     ...  ...  ...   ...    ...       ...    ...         ...
# 871         1       1    1    2     2      4         0      2           2
# 872         0       1    0    1     0      2         0      0           0
# 879         1       1    1    2     2      3         1      2           1
# 887         1       1    1    1     1      2         0      1           0
# 889         1       1    0    1     1      3         1      0           0
#
# [183 rows x 9 columns]

# %%
test
# Out:
#      PassengerId  Pclass  Sex  Age  Fare  Cabin  Embarked  Title  FamilySize
# 12           904       1    1    1     2      2         0      2           1
# 14           906       1    1    2     2      5         0      2           1
# 24           916       1    1    2     3      2         1      2           4
# 26           918       1    1    1     2      2         1      1           1
# 28           920       1    0    2     1      1         0      0           0
# ..           ...     ...  ...  ...   ...    ...       ...    ...         ...
# 404         1296       1    0    2     1      4         1      0           1
# 405         1297       2    0    1     0      4         1      0           0
# 407         1299       1    0    2     3      3         1      0           2
# 411         1303       1    1    1     2      3         2      2           1
# 414         1306       1    1    2     2      3         1      3           0
#
# [87 rows x 9 columns]

# %% [markdown]
# ## 매핑 완료

# %% [markdown]
# # 모델링

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ## KNN

# %%
clf = KNeighborsClassifier(n_neighbors = 13) # 모델 생성
scoring = 'accuracy'
# cross_validate(모델 객체, 훈련 인풋, 훈련 타겟)
score1 = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)

round(np.mean(score1)*100, 2)
# Out:
# 74.74

# %% [markdown]
# ## 의사결정 나무

# %%
clf = DecisionTreeClassifier()
score2 = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)

round(np.mean(score2)*100, 2)
# Out:
# 68.86

# %% [markdown]
# ## 랜덤포레스트

# %%
clf = RandomForestClassifier(n_estimators=13)
score3 = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)

round(np.mean(score3)*100, 2)
# Out:
# 70.99

# %% [markdown]
# ## 나이브 베이즈

# %%
clf = GaussianNB()
score4 = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)

round(np.mean(score4)*100, 2)
# Out:
# 78.07
